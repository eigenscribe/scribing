# %% [markdown]
# # Pandas Brain Teasers

# %%
import sys
sys.path.append('/workspaces/scribing/')
import pandas as pd
import numpy as np

# %% [markdown]
# ## Relational Operators with Pandas Series
#
# A `ValueError` is raised when a function gets an argument of correct type but improper value.
#
# ### Universal Functions
# Definition: A function that works on a scaler, `pandas.Series` and a NumPy array is called a `ufunc()`, which is short for **universal function**.
#
# > 📝 Note: Most of the functions from NumPy or Pandas, such as `min()` or `to_datetime()`, are universal functions (`ufun()`).
#
#
# NumPy has a `@vectorize` decorator for converting scalar functions to `ufunc()`.
#
# In the code below, pay attention to types. The output of `relu(n)` is of type `numpy.ndarray`, not `pandas.Series`.

# %%
@np.vectorize   

def relu(n):
  if n < 0:
    return 0
  return n
    
arr = pd.Series([-1, 0, 1])
print(relu(arr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspaces/scribing/notebooks/pandas_brain_teasers.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bliterate-broccoli-wrggrq9qxr4rhg4jj/workspaces/scribing/notebooks/pandas_brain_teasers.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> @np.vectorize
#       <a href='vscode-notebook-cell://codespaces%2Bliterate-broccoli-wrggrq9qxr4rhg4jj/workspaces/scribing/notebooks/pandas_brain_teasers.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell://codespaces%2Bliterate-broccoli-wrggrq9qxr4rhg4jj/workspaces/scribing/notebooks/pandas_brain_teasers.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> def relu(n):
#       <a href='vscode-notebook-cell://codespaces%2Bliterate-broccoli-wrggrq9qxr4rhg4jj/workspaces/scribing/notebooks/pandas_brain_teasers.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>   if n < 0:
#       <a href='vscode-notebook-cell://codespaces%2Bliterate-broccoli-wrggrq9qxr4rhg4jj/workspaces/scribing/notebooks/pandas_brain_teasers.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     return 0
#
# NameError: name 'np' is not defined
