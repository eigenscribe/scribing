# %%
import sys
import os

# Add the parent directory to sys.path so that 'utils' can be imported
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.phase_linear_2D import phase_portrait, set_plot_style

import numpy as np
import matplotlib.pyplot as plt

#set_plot_style("dark_background")

# %%
# Example 1: non-singular
A1 = np.array([[2, 1],
               [1, -1]], dtype=float)

phase_portrait(A1)

# %%
# Example 2: singular (line of fixed points)
A2 = np.array([[1, 0],
               [0, 0]], dtype=float)

phase_portrait(A2)
